# %% [markdown]
# # Project IRGPUA

# %% [markdown]
# ## Setup

# %% [markdown]
# 1. Select GPU as an execution environnement
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Check that the GPU is indeed detected (you should see nvidia-smi output with Tesla T4 as a GPU)

# %%
# !nvidia-smi
# Out:
# Tue Sep 17 16:48:30 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# 3. Install conda (kernel will be restarted which is normal)

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %% [markdown]
# 4. Install the conda env (should take around 4 minutes)

# %%
# !mamba install -c rapidsai -c nvidia -c conda-forge -c defaults cuda=12.2 cuda-version=12.2 rmm benchmark cmake=3.30 raft-dask pylibraft
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Extracting  (148)  ⣾  [+] 55.4s
# ...
# Extracting  (148)  ⣾  [+] 55.5s
# ...
# Extracting  (148)  ⣾  [+] 55.6s
# ...
# Extracting  (148)  ⣾  [+] 55.7s
# ...
# Extracting  (148)  ⣾  [+] 55.8s
# ...
# Extracting  (148)  ⣾  [+] 55.9s
# ...
# Extracting  (148)  ⣾  [+] 56.0s
# ...
# Extracting  (148)  ⣾  [+] 56.1s
# ...
# Extracting  (148)  ⣾  [+] 56.2s
# ...
# Extracting  (148)  ⣾  [+] 56.3s
# ...
# Extracting  (148)  ⣾  [+] 56.4s
# ...
# Extracting  (148)  ⣾  [+] 56.5s
# ...
# Extracting  (148)  ⣾  [+] 56.6s
# ...
# Extracting  (148)  ⣾  [+] 56.7s
# ...
# Extracting  (148)  ⣾  [+] 56.8s
# ...
# Extracting  (148)  ⣾  [+] 56.9s
# ...
# Extracting  (148)  ⣾  [+] 57.0s
# ...
# Extracting  (148)  ⣾  [+] 57.1s
# ...
# Extracting  (148)  ⣾  [+] 57.2s
# ...
# Extracting  (148)  ⣾  [+] 57.3s
# ...
# Extracting  (148)  ⣾  [+] 57.4s
# ...
# Extracting  (148)  ⣾  [+] 57.5s
# ...
# Extracting  (148)  ⣾  [+] 57.6s
# ...
# Extracting  (148)  ⣾  [+] 57.7s
# ...
# Extracting  (148)  ⣾  [+] 57.8s
# ...
# Extracting  (148)  ⣾  [+] 57.9s
# ...
# Extracting  (148)  ⣾  [+] 58.0s
# ...

# %% [markdown]
# 5. Download the project

# %%
# !wget https://cloud.lrde.epita.fr/s/aHxj4yQ7rR3iTYr/download/project_student_colab.zip
# !unzip project_student_colab.zip
# Out:
# --2024-09-17 17:06:27--  https://cloud.lrde.epita.fr/s/aHxj4yQ7rR3iTYr/download/project_student_colab.zip
# Resolving cloud.lrde.epita.fr (cloud.lrde.epita.fr)... 91.243.117.236
# Connecting to cloud.lrde.epita.fr (cloud.lrde.epita.fr)|91.243.117.236|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27862896 (27M) [application/zip]
# Saving to: ‘project_student_colab.zip’
#
# project_student_col 100%[===================>]  26.57M  4.63MB/s    in 7.0s
#
# 2024-09-17 17:06:35 (3.81 MB/s) - ‘project_student_colab.zip’ saved [27862896/27862896]
#
# Archive:  project_student_colab.zip
#    creating: project_student_colab/
#   inflating: project_student_colab/CMakeLists.txt
#    creating: project_student_colab/images/
#   inflating: project_student_colab/images/Broken#0.pgm
#   inflating: project_student_colab/images/Broken#1.pgm
#   inflating: project_student_colab/images/Broken#10.pgm
#   inflating: project_student_colab/images/Broken#11.pgm
# ...

# %% [markdown]
# 6. Verify compilation & execution (second test should fail)

# %%
# !cd project_student_colab && mkdir build && cd build && cmake .. && make -j
# !cd ./project_student_colab/build && ./main
# Out:
# mkdir: cannot create directory ‘build’: File exists
# File loading...
# Done, starting compute
# Done with compute, starting stats
# Image #22 total : 268424419
# Image #11 total : 78632198
# Image #2 total : 342970490
# Image #21 total : 207334021
# Image #26 total : 80124196
# Image #12 total : 491605096
# Image #18 total : 104275727
# Image #27 total : 29256842
# Image #7 total : 118842538
# Image #19 total : 30603818
# Image #8 total : 72434629
# Image #4 total : 390348481
# Image #29 total : 34550754
# Image #24 total : 51973720
# Image #17 total : 70004942
# Image #20 total : 6496225
# Image #14 total : 111786760
# Image #25 total : 24489209
# Image #6 total : 10825197
# Image #9 total : 191735142
# Image #28 total : 25803206
# Image #5 total : 91297791
# Image #23 total : 432916359
# Image #1 total : 185010925
# Image #15 total : 406461934
# Image #13 total : 8109782
# Image #0 total : 27805567
# Image #3 total : 33055988
# Image #16 total : 80671811
# ...

# %% [markdown]
# ## Project

# %% [markdown]
# Just like in the Colab's version of other hands-on, you will have to create code box to modify the code.
#
# They usually take the form of:
#
# %%file /content/project_student_colab/src/file.cu
#
# Example below:

# %%
# %%file /content/project_student_colab/src/file.cu # TODO PUT A CORRECT FILEPATH HERE
#
# // Some code

# %% [markdown]
# Sadly you will have to create one code block for each file you want to modify or new file you want to create.
#
# Do know that you have access to all bash command (mkdir, ls, touch...) to interact with your files in this Google Colab env by creating a new code block and using the !. For example !ls will execute ls in the current Google Colab folder.
#
# Once you are done with everything go to final step: compile and run.

# %% [markdown]
# - Compile and run

# %%
# !cd ./project_student_colab/build && make -j && ./main
# Out:
# [100%] Built target main
# File loading...
# Done, starting compute
# Done with compute, starting stats
# Image #22 total : 268424419
# Image #11 total : 78632198
# Image #2 total : 342970490
# Image #21 total : 207334021
# Image #26 total : 80124196
# Image #12 total : 491605096
# Image #18 total : 104275727
# Image #27 total : 29256842
# Image #7 total : 118842538
# Image #19 total : 30603818
# Image #8 total : 72434629
# Image #4 total : 390348481
# Image #29 total : 34550754
# Image #24 total : 51973720
# Image #17 total : 70004942
# Image #20 total : 6496225
# Image #14 total : 111786760
# Image #25 total : 24489209
# Image #6 total : 10825197
# Image #9 total : 191735142
# Image #28 total : 25803206
# Image #5 total : 91297791
# Image #23 total : 432916359
# Image #1 total : 185010925
# Image #15 total : 406461934
# Image #13 total : 8109782
# Image #0 total : 27805567
# Image #3 total : 33055988
# Image #16 total : 80671811
# Image #10 total : 182802772
# ...
